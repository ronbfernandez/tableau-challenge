# %%
import pandas as pd

# %%
# create a DataFrame for citi-bike trip data.
df = pd.read_csv("JC-202105-citibike-tripdata.csv")

# %%
df.head()
# Out:
#             ride_id rideable_type           started_at             ended_at  \
# 0  74A4206E7487CBC9   docked_bike  2021-05-23 16:51:00  2021-05-23 18:38:21
# 1  58EEE2950FFE01CE   docked_bike  2021-05-31 16:54:47  2021-05-31 16:55:28
# 2  1429D912C16EEE59   docked_bike  2021-05-25 16:19:34  2021-05-25 17:03:06
# 3  FE9C5B74167CBCCD   docked_bike  2021-05-22 17:32:19  2021-05-22 17:41:27
# 4  B88D37626F000BBA   docked_bike  2021-05-14 09:48:34  2021-05-14 10:17:36
#
#               start_station_name start_station_id  \
# 0  9 St HBLR - Jackson St & 8 St            HB305
# 1  9 St HBLR - Jackson St & 8 St            HB305
# 2  9 St HBLR - Jackson St & 8 St            HB305
# 3  9 St HBLR - Jackson St & 8 St            HB305
# 4                       Union St            JC051
#
#                 end_station_name end_station_id  start_lat  start_lng  \
# 0  9 St HBLR - Jackson St & 8 St          HB305  40.747907 -74.038411
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45043 entries, 0 to 45042
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ride_id             45043 non-null  object
#  1   rideable_type       45043 non-null  object
#  2   started_at          45043 non-null  object
#  3   ended_at            45043 non-null  object
#  4   start_station_name  45043 non-null  object
#  5   start_station_id    45043 non-null  object
#  6   end_station_name    44954 non-null  object
#  7   end_station_id      44954 non-null  object
#  8   start_lat           45043 non-null  float64
#  9   start_lng           45043 non-null  float64
#  10  end_lat             44954 non-null  float64
#  11  end_lng             44954 non-null  float64
#  12  member_casual       45043 non-null  object
# dtypes: float64(4), object(9)
# memory usage: 4.5+ MB

# %%
#Renaming columns to better match description
df2 = df.rename(columns={"started_at":"start", "ended_at":"ended", "start_station_name":"station started", "end_station_name":"station arrived" })
df2
# Out:
#                 ride_id rideable_type                start  \
# 0      74A4206E7487CBC9   docked_bike  2021-05-23 16:51:00
# 1      58EEE2950FFE01CE   docked_bike  2021-05-31 16:54:47
# 2      1429D912C16EEE59   docked_bike  2021-05-25 16:19:34
# 3      FE9C5B74167CBCCD   docked_bike  2021-05-22 17:32:19
# 4      B88D37626F000BBA   docked_bike  2021-05-14 09:48:34
# ...                 ...           ...                  ...
# 45038  62FF3FEDAAD7FCB3   docked_bike  2021-05-31 12:46:22
# 45039  E742AEA7068E0E4A   docked_bike  2021-05-31 16:34:19
# 45040  E769F9EE96D6433A   docked_bike  2021-05-17 22:52:35
# 45041  EC973614DCA179A2   docked_bike  2021-05-31 20:48:58
# 45042  3571180FE5C52CB1   docked_bike  2021-05-23 14:28:43
#
#                      ended                station started start_station_id  \
# 0      2021-05-23 18:38:21  9 St HBLR - Jackson St & 8 St            HB305
# 1      2021-05-31 16:55:28  9 St HBLR - Jackson St & 8 St            HB305
# ...

# %%
# Export the Dataframe as a new CSV file without the index.
df.to_csv("NYC_CitiBike_Clean.csv", index=False)
